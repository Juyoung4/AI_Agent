# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

client = OpenAI(api_key=os.getenv("OPEN_AI_API_KEY"))

messges = [
    {"role": "system", "content": "너는 뛰어난 이미지 분석가야."},
    {"role": "user", "content" : [
        {"type" : "text", "text": "이 이미지에 대해서 설명해주세요."},
        {"type" : "image_url", "image_url": {"url": "https://images.unsplash.com/photo-1736264335247-8ec5664c8328?q=80&w=1887&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"}}
    ]
    }
]

# %%
response = client.chat.completions.create(
    model="gpt-5-mini",
    messages=messges
)

response
# Out:
# ChatCompletion(id='chatcmpl-CqxLnVAWWvOTlwwd6XRi5Y8wRoNto', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='밝고 자연스러운 분위기의 주방 장면입니다. 화면 중앙에 젊은 여성(성인으로 보임)이 서서 파란 그릇에 든 달걀을 거품기로 휘젓고 있고, 얼굴에 미소를 짓고 있습니다. 그녀는 블랙 운동복(스포츠 브라와 하이웨이스트 레깅스)을 입고 머리는 포니테일로 묶었으며, 손목에 스마트워치와 얇은 목걸이를 착용하고 있습니다.\n\n왼쪽에는 프라이팬에 베이컨처럼 보이는 두 줄이 익고 있고, 작업대는 스테인리스 소재로 보입니다. 뒤쪽으로는 큰 창문으로 밝은 실외 풍경(초원이나 나무 라인)이 보이며, 사진은 세로 구도로 인물과 조리대에 초점을 맞춘 구도입니다. 전체적으로 따뜻하고 일상적인 “아침을 준비하는” 순간을 포착한 이미지이며, 약간 필름 같은 그레인과 콘트라스트가 강조된 편집 느낌입니다.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1766737235, model='gpt-5-mini-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=569, prompt_tokens=1776, total_tokens=2345, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=320, rejected_prediction_token
# ...

# %%
response.choices[0].message.content
# Out:
# '밝고 자연스러운 분위기의 주방 장면입니다. 화면 중앙에 젊은 여성(성인으로 보임)이 서서 파란 그릇에 든 달걀을 거품기로 휘젓고 있고, 얼굴에 미소를 짓고 있습니다. 그녀는 블랙 운동복(스포츠 브라와 하이웨이스트 레깅스)을 입고 머리는 포니테일로 묶었으며, 손목에 스마트워치와 얇은 목걸이를 착용하고 있습니다.\n\n왼쪽에는 프라이팬에 베이컨처럼 보이는 두 줄이 익고 있고, 작업대는 스테인리스 소재로 보입니다. 뒤쪽으로는 큰 창문으로 밝은 실외 풍경(초원이나 나무 라인)이 보이며, 사진은 세로 구도로 인물과 조리대에 초점을 맞춘 구도입니다. 전체적으로 따뜻하고 일상적인 “아침을 준비하는” 순간을 포착한 이미지이며, 약간 필름 같은 그레인과 콘트라스트가 강조된 편집 느낌입니다.'

# %%
# 로컬 이미지로 이미지 분석 요청하기
import base64

def encode_image_to_base64(image_path):
    with open(image_path, "rb") as img:
        return base64.b64encode(img.read()).decode("utf-8")

image_base64 = encode_image_to_base64("./data/디즈니컴퓨터배경화면04.jpg")

image_base64
# Out:
# '...'

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()

client = OpenAI(api_key=os.getenv("OPEN_AI_API_KEY"))

messges = [
    {"role": "system", "content": "너는 뛰어난 이미지 분석가야."},
    {"role": "user", "content" : [
        {"type" : "text", "text": "이 이미지에 대해서 설명해주세요."},
        {"type" : "image_url", "image_url": {"url": f"data:image/jpg;base64,{image_base64}"}}
    ]
    }
]

# %%
response = client.chat.completions.create(
    model="gpt-5-mini",
    messages=messges
)

response
# Out:
# ChatCompletion(id='chatcmpl-CqxRM69UlGVqjfq56YyNsaLBERyCG', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='짧히 말하면: 디즈니 애니메이션 영화 「라이온 킹」의 유명한 장면으로, 커다란 보름달을 배경으로 사자(심바), 멧돼지(품바), 미어캣(티몬) 세 친구가 통나무 다리를 걸어가는 야간 실루엣 샷입니다.\n\n세부 묘사:\n- 화면 중앙에 거의 꽉 차게 떠 있는 밝은 보름달이 인상적이며, 인물들을 뒤에서 은은하게 역광으로 비춥니다.\n- 왼쪽에 갈기 있는 성인 수사자가 당당하게 걷고 있고(심바로 보임), 가운데에 몸집이 둥근 멧돼지(품바), 오른쪽 끝에는 작은 미어캣(티몬)이 두 발로 성큼성큼 걷고 있습니다.\n- 이들은 협곡 위의 굵은 통나무(다리)를 가로질러 이동하고 있으며, 통나무 표면의 이끼와 아래로 내려다보이는 어두운 심연이 보입니다.\n- 전체 색조는 밤의 푸른 톤이 주를 이루고 달빛의 흰빛이 대비를 만들어 드라마틱한 분위기를 냅니다.\n- 구도는 삼인(三人)을 가로로 정렬시키고 중앙의 달을 배경으로 삼아 우정과 모험, 쓸쓸하면서도 따뜻한 감정을 동시에 전달합니다.\n- 스타일은 전형적인 2D 디즈니 애니메이션 연출입니다. 이 장면은 영화 속에서 편안함과 자유를 노래하는 ‘Hakuna Matata’ 몽타주와 연결되는 이미지로 널리 알려져 있습니다.\n\n원하시면 이 장면의 의미나 장면이 등장하는 영화 속 맥락(줄거리·음악 등)에 대해서도 더 설명해 드릴게요.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1766737580, model='gpt-5-mini-2025-08-07', object='chat.completion
# ...

# %%
response.choices[0].message.content
# Out:
# '짧히 말하면: 디즈니 애니메이션 영화 「라이온 킹」의 유명한 장면으로, 커다란 보름달을 배경으로 사자(심바), 멧돼지(품바), 미어캣(티몬) 세 친구가 통나무 다리를 걸어가는 야간 실루엣 샷입니다.\n\n세부 묘사:\n- 화면 중앙에 거의 꽉 차게 떠 있는 밝은 보름달이 인상적이며, 인물들을 뒤에서 은은하게 역광으로 비춥니다.\n- 왼쪽에 갈기 있는 성인 수사자가 당당하게 걷고 있고(심바로 보임), 가운데에 몸집이 둥근 멧돼지(품바), 오른쪽 끝에는 작은 미어캣(티몬)이 두 발로 성큼성큼 걷고 있습니다.\n- 이들은 협곡 위의 굵은 통나무(다리)를 가로질러 이동하고 있으며, 통나무 표면의 이끼와 아래로 내려다보이는 어두운 심연이 보입니다.\n- 전체 색조는 밤의 푸른 톤이 주를 이루고 달빛의 흰빛이 대비를 만들어 드라마틱한 분위기를 냅니다.\n- 구도는 삼인(三人)을 가로로 정렬시키고 중앙의 달을 배경으로 삼아 우정과 모험, 쓸쓸하면서도 따뜻한 감정을 동시에 전달합니다.\n- 스타일은 전형적인 2D 디즈니 애니메이션 연출입니다. 이 장면은 영화 속에서 편안함과 자유를 노래하는 ‘Hakuna Matata’ 몽타주와 연결되는 이미지로 널리 알려져 있습니다.\n\n원하시면 이 장면의 의미나 장면이 등장하는 영화 속 맥락(줄거리·음악 등)에 대해서도 더 설명해 드릴게요.'
