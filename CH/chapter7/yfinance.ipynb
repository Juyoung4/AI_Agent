# %%
import yfinance as yf

# microsoft에 대한 ticker 객체 생성 => 티커란 주식 종목을 식별하는 고유 코드
msft = yf.Ticker("MSFT") # MSFT = 마이크로소프트

# Ticker 객체를 사용하여 정보 접근
display(msft.info) # 기본정보
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
hist = msft.history(period="5d") # 최근 5일간의 주가 데이터
display(hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-12-23 00:00:00-05:00  484.980011  487.829987  484.739990  486.850006
# 2025-12-24 00:00:00-05:00  485.679993  489.160004  484.829987  488.019989
# 2025-12-26 00:00:00-05:00  486.709991  488.119995  485.959991  487.709991
# 2025-12-29 00:00:00-05:00  484.859985  488.350006  484.179993  487.100006
# 2025-12-30 00:00:00-05:00  485.929993  489.679993  485.500000  487.480011
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-12-23 00:00:00-05:00  14683600        0.0           0.0
# 2025-12-24 00:00:00-05:00   5855900        0.0           0.0
# 2025-12-26 00:00:00-05:00   8842200        0.0           0.0
# 2025-12-29 00:00:00-05:00  10893400        0.0           0.0
# 2025-12-30 00:00:00-05:00  13915900        0.0           0.0
